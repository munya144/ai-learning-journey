# %%
# ЗАДАЧА 1: Tokenizer Types (3 часа)

# TODO для каждого:
# 1. Токенизировать одинаковый текст
# 2. Сравнить результаты
# 3. Понять: vocab size, subword tokenization
# 4. Special tokens: [CLS], [SEP], <|endoftext|>

# ЗАДАЧА 2: Custom Tokenizer (2 часа)

# TODO:
# 1. Обучить свой BPE tokenizer на маленьком корпусе
# 2. Сравнить с pretrained
# 3. Понять: когда нужен custom tokenizer

# ЗАДАЧА 3: Encoding/Decoding (2 часа)
# TODO:
# 1. encode() vs tokenize()
# 2. Padding и truncation
# 3. attention_mask
# 4. return_tensors='pt'
